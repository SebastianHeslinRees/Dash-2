# %% [markdown]
# # EQUALITIES EXPLORER DASHBOARD

# %% [markdown]
# ### Import packages

# %%
#import packages
import os
import pandas as pd
import numpy
import plotly.express as px  # (version 4.7.0 or higher)
import plotly.graph_objects as go
#from dash import Dash, dcc, html, Input, Output  # pip install dash (version 2.0.0 or higher)
from skimage import io

# %%
#import dash libaries
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output, Input
import dash_bootstrap_components as dbc

# %%
#import dash table libaries
import dash_table
from dash_table.Format import Format, Group
import dash_table.FormatTemplate as FormatTemplate
from datetime import datetime as dt

# %%
#set app
app = dash.Dash()

# %% [markdown]
# ### Import data

# %%
#importing mirco census data
os.chdir(r"C:\Users\SHRees\OneDrive - TrIS\Equalities and Disparities - Characteristics Interaction Report\Datasets")
region_mirco_census = pd.read_csv('cleaned_150000.csv')

# %%
#importing mirco census data
#os.chdir(r"C:\Users\SHRees\OneDrive - TrIS\Equalities and Disparities - Characteristics Interaction Report\Datasets")
#region_mirco_census = pd.read_csv('cleaned_150000.csv')
#region_mirco_census = pd.read_csv('cleaned_full.csv')

# %%
region_mirco_census
# Out:
#        Characteristic - Age           Characteristic - Disability  \
# 0                     60-79     Day-to-day activities not limited
# 1                     40-59     Day-to-day activities not limited
# 2                     40-59     Day-to-day activities not limited
# 3                     20-39  Persons who are not a usual resident
# 4                     20-39     Day-to-day activities not limited
# ...                     ...                                   ...
# 149995                40-59     Day-to-day activities not limited
# 149996                20-39     Day-to-day activities not limited
# 149997                20-39     Day-to-day activities not limited
# 149998                40-59     Day-to-day activities not limited
# 149999                 0-19     Day-to-day activities not limited
#
#                                Characteristic - Ethnicity  \
# 0       White: English/Welsh/Scottish/Northern Irish/B...
# 1       White: English/Welsh/Scottish/Northern Irish/B...
# 2       White: English/Welsh/Scottish/Northern Irish/B...
# 3        Student/schoolchild living away during term-time
# 4       White: English/Welsh/Scottish/Northern Irish/B...
# ...                                                   ...
# 149995                   Asian/Asian British: Other Asian
# 149996                       Asian/Asian British: Chinese
# 149997  White: English/Welsh/Scottish/Northern Irish/B...
# 149998  White: English/Welsh/Scottish/Northern Irish/B...
# 149999                     Asian/Asian British: Pakistani
#
#                           Characteristic - Marital Status  \
# 0                                                 Married
# 1                                                 Married
# 2                                                 Married
# 3       Single (never married/never registered same-se...
# 4       Single (never married/never registered same-se...
# ...                                                   ...
# 149995  Divorced / Formerly in a same-sex civil partne...
# 149996  Single (never married/never registered same-se...
# 149997                                            Married
# 149998                                            Married
# 149999  Single (never married/never registered same-se...
#
#                                Characteristic - Religion   \
# 0       Christian (including Church of England, Cathol...
# 1       Christian (including Church of England, Cathol...
# 2                                             No religion
# 3        Student/schoolchild living away during term-time
# 4                                             No religion
# ...                                                   ...
# 149995  Christian (including Church of England, Cathol...
# 149996  Christian (including Church of England, Cathol...
# 149997  Christian (including Church of England, Cathol...
# 149998  Christian (including Church of England, Cathol...
# 149999                                             Muslim
#
#        Characteristic - Sex Education - Household Education Deprivation  \
# 0                    Female         Not deprived in education dimension
# 1                      Male         Not deprived in education dimension
# 2                    Female         Not deprived in education dimension
# 3                    Female         Not deprived in education dimension
# 4                      Male             Deprived in education dimension
# ...                     ...                                         ...
# 149995               Female         Not deprived in education dimension
# 149996               Female                                       Other
# 149997               Female             Deprived in education dimension
# 149998                 Male         Not deprived in education dimension
# 149999               Female         Not deprived in education dimension
#
#        Education - In Full-Time Education  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                     Yes
# 4                                      No
# ...                                   ...
# 149995                                 No
# 149996                                Yes
# 149997                                 No
# 149998                                 No
# 149999                                Yes
#
#               Education - Level of Highest Qualifications  \
# 0              No academic or professional qualifications
# 1              No academic or professional qualifications
# 2       Level 4+: Degree (BA, BSc), Higher Degree (MA,...
# 3       Persons aged under 16 OR student/schoolchild l...
# 4       Level 2: 5+ O Level (Passes)/CSEs (Grade 1)/GC...
# ...                                                   ...
# 149995  Level 4+: Degree (BA, BSc), Higher Degree (MA,...
# 149996  Level 2: 5+ O Level (Passes)/CSEs (Grade 1)/GC...
# 149997         No academic or professional qualifications
# 149998                                     Apprenticeship
# 149999  Persons aged under 16 OR student/schoolchild l...
#
#                          Employment - Economically Active  ...  \
# 0                          Economically Inactive, Retired  ...
# 1       Economically Active( excluding Full-time Stude...  ...
# 2                          Economically Inactive, Retired  ...
# 3       Persons aged under 16 OR student/schoolchild l...  ...
# 4       Economically Active (excluding Full-time Stude...  ...
# ...                                                   ...  ...
# 149995  Economically Active( excluding Full-time Stude...  ...
# 149996                     Economically Inactive, Student  ...
# 149997  Economically Active (excluding Full-time Stude...  ...
# 149998  Economically Active( excluding Full-time Stude...  ...
# 149999  Persons aged under 16 OR student/schoolchild l...  ...
#
#        Housing - Household Housing Deprivation              Housing - Tenure  \
# 0        Not deprived in the housing dimension                         Other
# 1        Not deprived in the housing dimension                         Other
# 2        Not deprived in the housing dimension                         Other
# 3            Deprived in the housing dimension  Owns with a mortgage or loan
# 4        Not deprived in the housing dimension                 Owns outright
# ...                                        ...                           ...
# 149995       Deprived in the housing dimension                 Owns outright
# 149996      Households with no usual residents                         Other
# 149997   Not deprived in the housing dimension  Owns with a mortgage or loan
# 149998   Not deprived in the housing dimension                         Other
# 149999   Not deprived in the housing dimension                         Other
#
#                                   Housing - Type of House  \
# 0                        Detached whole house or bungalow
# 1                   Semi-detached whole house or bungalow
# 2                   Semi-detached whole house or bungalow
# 3       A flat, maisonette or apartment that is in a p...
# 4                   Semi-detached whole house or bungalow
# ...                                                   ...
# 149995  A flat, maisonette or apartment that is in a p...
# 149996                                              Other
# 149997              Semi-detached whole house or bungalow
# 149998              Semi-detached whole house or bungalow
# 149999  Terraced whole house or bungalow (including en...
#
#                                Housing - Type of landlord  \
# 0               Households that do not rent accommodation
# 1               Households that do not rent accommodation
# 2               Households that do not rent accommodation
# 3                               Council (Local Authority)
# 4       Housing association, housing co-operative, cha...
# ...                                                   ...
# 149995  Housing association, housing co-operative, cha...
# 149996          Households that do not rent accommodation
# 149997                          Council (Local Authority)
# 149998          Households that do not rent accommodation
# 149999          Households that do not rent accommodation
#
#                                 Housing - central heating  \
# 0                                     Gas central heating
# 1                                     Gas central heating
# 2                                     Gas central heating
# 3                                     Gas central heating
# 4                                     Oil central heating
# ...                                                   ...
# 149995  Electric (including storage heaters) central h...
# 149996                 Households with no usual residents
# 149997                                Gas central heating
# 149998                                Gas central heating
# 149999                                Gas central heating
#
#                    Transport - Distance Travelled to Work  \
# 0       Student/schoolchild living away during term-ti...
# 1                                            10 to <20 km
# 2       Student/schoolchild living away during term-ti...
# 3       Student/schoolchild living away during term-ti...
# 4       Student/schoolchild living away during term-ti...
# ...                                                   ...
# 149995                                       10 to <20 km
# 149996  Student/schoolchild living away during term-ti...
# 149997  Student/schoolchild living away during term-ti...
# 149998                                       10 to <20 km
# 149999  Student/schoolchild living away during term-ti...
#
#                      Transport - Live and Work Comparison  \
# 0       Persons aged under 16 OR student/schoolchild l...
# 1       Lives outside LA/UA/LGD area of workplace but ...
# 2       Persons aged under 16 OR student/schoolchild l...
# 3       Persons aged under 16 OR student/schoolchild l...
# 4       Persons aged under 16 OR student/schoolchild l...
# ...                                                   ...
# 149995  Lives outside LA/UA/LGD area of workplace but ...
# 149996  Persons aged under 16 OR student/schoolchild l...
# 149997  Persons aged under 16 OR student/schoolchild l...
# 149998  Lives outside LA/UA/LGD area of workplace but ...
# 149999  Persons aged under 16 OR student/schoolchild l...
#
#                       Transport - Number of cars and vans  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 149995                                                  1
# 149996  Households with no usual residents OR communal...
# 149997                                               None
# 149998                                                  2
# 149999                                                  2
#
#                       Transport - Travel to Work Mode  \
# 0       People not in work the week before Census day
# 1                                Driving a car or van
# 2       People not in work the week before Census day
# 3       People not in work the week before Census day
# 4       People not in work the week before Census day
# ...                                               ...
# 149995                                          Train
# 149996  People not in work the week before Census day
# 149997  People not in work the week before Census day
# 149998           Underground, metro, light rail, tram
# 149999  People not in work the week before Census day
#
#                        UK region
# 0                     North West
# 1                  East Midlands
# 2                  East Midlands
# 3                   Outer London
# 4                East of England
# ...                          ...
# 149995              Outer London
# 149996                North West
# 149997  Yorkshire and the Humber
# 149998              Outer London
# 149999             West Midlands
#
# [150000 rows x 37 columns]

# %% [markdown]
# ### Set HMT corporate styling

# %%
corporate_colors = {
    'dark-blue-grey' : 'rgb(62, 64, 76)',
    'medium-blue-grey' : 'rgb(77, 79, 91)',
    'medium-blue' : 'rgb(27,167,201)',
    'superdark-green' : 'rgb(41, 56, 55)',
    'dark-green' : 'rgb(57, 81, 85)',
    'medium-green' : 'rgb(51, 153, 102)',
    'light-green' : 'rgb(186, 218, 212)',
    'pink-red' : 'rgb(255, 101, 131)',
    'dark-pink-red' : 'rgb(247, 80, 99)',
    'burnt-orange':'rgb(222,139,9)',
    'white' : 'rgb(251, 251, 252)',
#'light-green' : 'rgb(208, 206, 206)',
    'red':'rgb(200, 0, 0)',
}

externalgraph_rowstyling = {
    'margin-left' : '15px',
    'margin-right' : '15px'
}

externalgraph_colstyling = {
    'border-radius' : '10px',
    'border-style' : 'solid',
    'border-width' : '1px',
    'border-color' : corporate_colors['superdark-green'],
    'background-color' : corporate_colors['superdark-green'],
    'box-shadow' : '0px 0px 17px 0px rgba(186, 218, 212, .5)',
    'padding-top' : '10px'
}

filterdiv_borderstyling = {
    'border-radius' : '0px 0px 10px 10px',
    'border-style' : 'solid',
    'border-width' : '1px',
    'border-color' : corporate_colors['light-green'],
    'background-color' : corporate_colors['light-green'],
    'box-shadow' : '2px 5px 5px 1px rgba(255, 101, 131, .5)'
    }

filterdiv_borderstyling2 = {
    'border-radius' : '0px 0px 10px 10px',
    'border-style' : 'solid',
    'border-width' : '1px',
    'border-color' : corporate_colors['dark-green'],
    'background-color' : corporate_colors['dark-green'],
    'box-shadow' : '2px 5px 5px 1px rgba(255, 101, 131, .5)'
    }

navbarcurrentpage = {
    'text-decoration' : 'underline',
    'text-decoration-color' : corporate_colors['pink-red'],
    'text-shadow': '0px 0px 1px rgb(251, 251, 252)'
    }

recapdiv = {
    'border-radius' : '10px',
    'border-style' : 'solid',
    'border-width' : '1px',
    'border-color' : 'rgb(251, 251, 252, 0.1)',
    'margin-left' : '15px',
    'margin-right' : '15px',
    'margin-top' : '15px',
    'margin-bottom' : '15px',
    'padding-top' : '5px',
    'padding-bottom' : '5px',
    'background-color' : 'rgb(251, 251, 252, 0.1)'
    }

recapdiv_text = {
    'text-align' : 'left',
    'font-weight' : '350',
    'color' : corporate_colors['white'],
    'font-size' : '1.5rem',
    'letter-spacing' : '0.04em'
    }

##################### Corporate chart formatting

corporate_title = {
    'font' : {
        'size' : 16,
        'color' : corporate_colors['white']}
}

corporate_xaxis = {
    'showgrid' : False,
    'linecolor' : corporate_colors['light-green'],
    'color' : corporate_colors['light-green'],
    'titlefont' : {
        'size' : 16,
        'color' : corporate_colors['light-green']},
    'tickfont' : {
        'size' : 11,
        'color' : corporate_colors['light-green']},
    'zeroline': False
}

corporate_yaxis = {
    'showgrid' : True,
    'color' : corporate_colors['dark-green'],
    'gridwidth' : 0.5,
    'gridcolor' : corporate_colors['light-green'],
    'linecolor' : corporate_colors['dark-green'],
    'titlefont' : {
        'size' : 16,
        'color' : corporate_colors['light-green']},
    'tickfont' : {
        'size' : 11,
        'color' : corporate_colors['light-green']},
    'zeroline': False
}

corporate_font_family = 'Dosis'

corporate_legend = {
    'orientation' : 'h',
    'yanchor' : 'bottom',
    'y' : 1.01,
    'xanchor' : 'right',
    'x' : 1.05,
	'font' : {'size' : 9, 'color' : corporate_colors['light-green']}
} # Legend will be on the top right, above the graph, horizontally

corporate_margins = {'l' : 5, 'r' : 5, 't' : 45, 'b' : 15}  # Set top margin to in case there is a legend

corporate_layout = go.Layout(
    font = {'family' : corporate_font_family},
    title = corporate_title,
    title_x = 0.5, # Align chart title to center
    paper_bgcolor = 'rgba(0,0,0,0)',
    plot_bgcolor = 'rgba(0,0,0,0)',
    xaxis = corporate_xaxis,
    yaxis = corporate_yaxis,
    height = 270,
    legend = corporate_legend,
    margin = corporate_margins
    )

# %% [markdown]
# ### Define reusable components as functions
# ### Header

# %%
def get_header():
    header = html.Div([
        html.Div([], className = 'col-2'), #Same as img width, allowing to have the title centrally aligned
       
        html.Div([
            html.Img(
                    src = app.get_asset_url('logo_001c.png'),
                    height = '43 px',
                    width = 'auto')
            ],
            className = 'col-2',
            style = {
                    'align-items': 'center',
                    'padding-top' : '1%',
                    'height' : 'auto'})
        ],
        className = 'row',
        style = {'height' : '4%',
                'background-color' : corporate_colors['superdark-green']}
        )
    return header

# %% [markdown]
# ### Empty row

# %%
def get_emptyrow(h='45px'):
    """This returns an empty row of a defined height"""
    emptyrow = html.Div([
        html.Div([
            html.Br()
        ], className = 'col-12')
    ],
    className = 'row',
    style = {'height' : h})
    return emptyrow

# %% [markdown]
# ### Layout

# %%
features = region_mirco_census.columns



app.layout = html.Div([
    
		html.Div([
        
         html.Div(html.Div([
      
            html.Div([
                html.H1(children='HMT Equalities Explorer',
                    style = {'color': corporate_colors['light-green'], 'textAlign' : 'center', 'font-family':'sans-serif'}
                )],
                className='col-8',
                style = {'padding-top' : '1%', 'padding-bottom' : '1%', 'background-color' : corporate_colors['dark-green']}
                    ),
        
            html.Div([
                html.Img(
                    src = 'https://publicappointments.cabinetoffice.gov.uk/wp-content/uploads/2018/02/HMT-logo.png',
                    height = '70 px',
                    width = 'auto')
                ],
                className = 'col-2',
                style = {
                    'align-items': 'center',
                    'padding-top' : '1%',
                    'height' : 'auto'})
                    ],
                className = 'row',
                style = {'height' : '4%',
                'background-color' : corporate_colors['light-green']}
                ), style = filterdiv_borderstyling)
            ]),
   
		html.Div([
            html.Div([
            html.Div([ html.Label('Select Characteristic: (x-axis)', 
                          style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif'}),
            dcc.Dropdown(
                id='slct_xaxis',
                options=[{'label': i, 'value': i} for i in features],
                value='Characteristic - Age',
                multi=False,
                style = {'font-family' : 'sans-serif', 'color' : corporate_colors['dark-green']}
                )], 
                 style={'width': '70%', 'padding-top' : '0.5%', 'padding-left' : '0.5%'}
                ),
    

            html.Div([
            
            html.Label('Select Second Characteristic:', 
                    style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif'}),
                dcc.Dropdown(id = "slct_xaxis2",
							multi = False,
							searchable = True,
#							value = "Characteristic - Ethnicity",
							options=[{'label': i, 'value': i} for i in features],
							className = "dcc_compon",
                            style = {'font-family' : 'sans-serif'})], 
                style={'width': '70%', 'padding-bottom' : '0.5%', 'padding-top' : '0.5%', 'padding-left' : '0.5%'}
        )], 
        
            style={'width': '49%', 'display': 'inline-block'}),
    
		html.Div([

            html.Div([html.Label('Select Variable(s) Within Second Characteristic:', 
                    style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif','padding-top' : '0.5%'}
                  ),
            dcc.Dropdown(
							id = "slct_v",
							multi = True,
							searchable = True,
							options = [],
							value = "",
							className = "dcc_compon"), 
            
                ], style = {'font-family' : 'sans-serif', 'width': '70%', 'padding-left' : '0.5%'}
            ),
    
        

            html.Div([html.Label('Select Region:', 
                          style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif'}),
            dcc.Dropdown(
                id = 'select_region',
                options = [{
                     'label' : i, 
                     'value' : i
                 } for i in region_mirco_census['UK region'].unique()],
                style = {'font-family' : 'sans-serif'})
                ], 
                style={'width': '70%','padding-top' : '0.5%', 'padding-left' : '0.5%'}
                )], 
            
            style={'width': '49%', 'display': 'inline-block'})
        ], style=filterdiv_borderstyling2),
    
 		html.Br(),
 
    dcc.Graph(id='feature-graphic', style={'padding-top' : '0.5%'}),
    
    html.H6("Based on Census microdata from The Office for National Statistics",  
            style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif'}),   
    html.H6("Please be aware that counts below 100 may not be an accurate representation of the population",  
            style={'color' : corporate_colors['light-green'], 'font-family' : 'sans-serif'}),
    
    html.Div(dash_table.DataTable(id = 'table',
                                  export_format="csv"))
    
], style = {'background-color' : corporate_colors['dark-green'],
            'box-shadow': '2px 5px 5px 1px rgba(255, 101, 131, .5)'})

# %% [markdown]
# ## Callbacks

# %% [markdown]
# ### Callback for third dropdown to select variables from second characteristic dropdown

# %%
@app.callback(
  Output(
    component_id = "slct_v",
    component_property = "options"
  ),
  Output(
    component_id = "slct_v",
    component_property = "value"
  ),
  Input(
    component_id = "slct_xaxis2",
    component_property = "value"
  )
)
def update_variable(slct_xaxis2):
  # Build list of variables
  list_of_variables = [{"label": i, "value": i} for i in region_mirco_census[slct_xaxis2].unique()]
  # Return list and value
  return list_of_variables, list_of_variables[0]["value"]

# %% [markdown]
# ### Graph callback

# %%
@app.callback(
    Output('feature-graphic', 'figure'),
    [Input('slct_xaxis', 'value'),
     Input('select_region', 'value'),
     Input('slct_xaxis2','value'),
     Input('slct_v', 'value')])

def update_graph(slct_xaxis, select_region, slct_xaxis2, slct_v):
    
    #order df so it can be in the same order as the custom data thus the hover is correct
    region_mirco_census.sort_values(slct_xaxis, inplace=True)

    #filter dataframe
    region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
    region_mirco_census_filtered_uk = region_mirco_census[region_mirco_census[slct_xaxis2].isin(slct_v)]
    region_mirco_census_filtered_region = region_mirco_census.loc[region_mirco_census['UK region'] == select_region]
    
    #set custom data for hovermode
    customdata_uk = region_mirco_census[slct_xaxis].value_counts().sort_index()
    customdata_region = region_mirco_census_filtered_region[slct_xaxis].value_counts().sort_index()
    customdata_uk_slct_variables = region_mirco_census_filtered_uk[slct_xaxis].value_counts().sort_index()
    customdata_region_slct_variables = region_mirco_census_filtered_region_and_slct_variable[slct_xaxis].value_counts().sort_index()
    
    #set varible name from column three and include spaces between mutliple varibles
    variable_name = ', '.join(slct_v)
    
    fig = go.Figure()

    fig.add_trace(
       
        go.Histogram(
            x=region_mirco_census_filtered_uk[slct_xaxis], customdata = customdata_uk_slct_variables, histnorm='percent', marker = dict(color=corporate_colors['light-green']),
            opacity=0.8, name= f"England & Wales and {variable_name}", hovertemplate='<b>Percenatge: %{y:.2f}</b><br>Count: %{customdata} <extra></extra>'
        )
    )

    fig.add_trace(
            go.Histogram(
                
                x=region_mirco_census_filtered_region_and_slct_variable[slct_xaxis], customdata = customdata_region_slct_variables, histnorm='percent',
                marker=dict(color='rgba(0,0,0,0)', line=dict(width=4, color= corporate_colors['medium-blue'])),
                opacity=0.8, name= f"{select_region} and {variable_name}", hovertemplate='<b>Percenatge: %{y:.2f}</b><br>Count: %{customdata} <extra></extra>'
            )
    )
    
    fig.add_trace(
            go.Histogram(
                
                x=region_mirco_census[slct_xaxis], customdata = customdata_uk, histnorm='percent', marker=dict(color='rgba(0,0,0,0)', line=dict(width=4, color=corporate_colors['burnt-orange'])),
                opacity=0.8, name="England & Wales", hovertemplate='<b>Percenatge: %{y:.2f}</b><br>Count: %{customdata} <extra></extra>'
            )
    )
    
    fig.add_trace(
            go.Histogram(
                
                x=region_mirco_census_filtered_region[slct_xaxis], customdata = customdata_region, histnorm='percent', marker=dict(color='rgba(0,0,0,0)', line=dict(width=4, color=corporate_colors['medium-green'])),
                opacity=0.8, name=f"{select_region}", hovertemplate='<b>Percenatge: %{y:.2f}</b><br>Count: %{customdata} <extra></extra>'
            )
    )
        
    fig.update_layout(height=750, barmode='overlay',
        margin=dict(l=20, r=20, t=20, b=70),  
        title = f" Distribution of {slct_xaxis}",
        font = {
        'size' : 16,
        'color' : corporate_colors['light-green']},
        xaxis_title = f"{slct_xaxis}",
        yaxis_title = "Percentage of Population",
        legend_title ="Please Click to Select Trace(s):",
#        title_pad_t = '1',
        title_y= 0.98,
        paper_bgcolor = 'rgba(0,0,0,0)',
        plot_bgcolor = 'rgba(0,0,0,0)',
        xaxis = corporate_xaxis,
        yaxis = corporate_yaxis,
        legend_font_family =  'sans-serif',
        legend_font_color = corporate_colors['light-green'],
        legend_font_size =15)

    fig.update_yaxes(range=[0, 100])

    #fig.show()
    return fig

# %% [markdown]
# ### Table callback

# %%
@app.callback(
    Output('table', 'data'),
    [Input('slct_xaxis', 'value'),
     Input('select_region', 'value'),
     Input('slct_xaxis2','value'),
     Input('slct_v', 'value')])

def update_table(slct_xaxis, select_region, slct_xaxis2, slct_v):
    
    #set varible name from column three and include spaces between mutliple varibles
    variable_name = ', '.join(slct_v)
    
    #filter dataframe
    region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
    region_mirco_census_filtered_uk = region_mirco_census[region_mirco_census[slct_xaxis2].isin(slct_v)]
    region_mirco_census_filtered_region = region_mirco_census.loc[region_mirco_census['UK region'] == select_region]
    
    #set customised data for different columns
    customdata_uk = pd.DataFrame(region_mirco_census[slct_xaxis].value_counts())
    customdata_uk.rename(columns={ customdata_uk.columns[0]: "England & Wales Count" }, inplace = True)
    customdata_region = pd.DataFrame(region_mirco_census_filtered_region[slct_xaxis].value_counts())
    customdata_region.rename(columns={ customdata_region.columns[0]: "Selected Region Count" }, inplace = True)
    customdata_uk_slct_variables = pd.DataFrame(region_mirco_census_filtered_uk[slct_xaxis].value_counts())
    customdata_uk_slct_variables.rename(columns={ customdata_uk_slct_variables.columns[0]: "England & Wales and Selected Variable Count" }, inplace = True)
    customdata_region_slct_variables = pd.DataFrame(region_mirco_census_filtered_region_and_slct_variable[slct_xaxis].value_counts())
    customdata_region_slct_variables.rename(columns={ customdata_region_slct_variables.columns[0]: "Select Region and Selected Variable Count" }, inplace = True)
    
    #concatenated variables
    combined_table = pd.concat([customdata_uk, customdata_uk_slct_variables, customdata_region, customdata_region_slct_variables], axis=1)
    
    #create percentage columns
    combined_table['England & Wales %'] = combined_table["England & Wales Count"] / combined_table["England & Wales Count"].sum() * 100
    combined_table[f'{select_region} %'] = combined_table["Selected Region Count"] / combined_table["Selected Region Count"].sum() * 100
    combined_table[f'England & Wales and {variable_name} %'] = combined_table["England & Wales and Selected Variable Count"] / combined_table["England & Wales and Selected Variable Count"].sum() * 100
    combined_table[f'{select_region} and {variable_name} %'] = combined_table["Select Region and Selected Variable Count"]/combined_table["Select Region and Selected Variable Count"].sum() * 100
    combined_table = combined_table.round(2)
    combined_table = combined_table.reset_index()
    combined_table = combined_table.rename(columns={'index': f"{slct_xaxis}", 
           'England & Wales and Selected Variable Count': f'England & Wales and {variable_name} count',
            "Selected Region Count":f'{select_region} count',
            "Select Region and Selected Variable Count" : f'{select_region} and {variable_name} count'})
    
    #re-order columns
    combined_table = combined_table[[f"{slct_xaxis}",'England & Wales Count', f'England & Wales and {variable_name} count',
                                     f'{select_region} count',
                                     f'{select_region} and {variable_name} count',
                                     'England & Wales %',
                                     f'England & Wales and {variable_name} %',
                                     f'{select_region} %',
                                     f'{select_region} and {variable_name} %']]
   
    #order the table to match the graph 
    combined_table.sort_values(slct_xaxis, inplace=True)
    
    
    return combined_table.to_dict('records')

# %%
if __name__ == '__main__':
    app.run_server(debug=False, port= 7662)
# Out:
# Dash is running on http://127.0.0.1:7662/
#
# Dash is running on http://127.0.0.1:7662/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:7662/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_2_0m1646135124.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_2_0m1646135124.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/deps/react@16.v2_2_0m1646135124.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_12_2m1623321558.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_2_0m1646135124.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_2_0m1646135124.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_2_0m1646135124.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:07] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_2_0m1646135124.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:08] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1646135124.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:08] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1646135124.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:08] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:08] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "GET /_favicon.ico?v=2.2.0 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-18-45de8645a51f>", line 17, in update_variable
#     list_of_variables = [{"label": i, "value": i} for i in region_mirco_census[slct_xaxis2].unique()]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-18-45de8645a51f>", line 17, in update_variable
#     list_of_variables = [{"label": i, "value": i} for i in region_mirco_census[slct_xaxis2].unique()]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:09] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [13/Apr/2022 16:29:15] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [13/Apr/2022 16:29:16] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [13/Apr/2022 16:29:16] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [13/Apr/2022 16:29:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-18-45de8645a51f>", line 17, in update_variable
#     list_of_variables = [{"label": i, "value": i} for i in region_mirco_census[slct_xaxis2].unique()]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-18-45de8645a51f>", line 17, in update_variable
#     list_of_variables = [{"label": i, "value": i} for i in region_mirco_census[slct_xaxis2].unique()]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [13/Apr/2022 16:29:48] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [13/Apr/2022 16:29:51] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-20-9324daab399f>", line 14, in update_table
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [13/Apr/2022 16:29:51] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-19-e17eb236cb49>", line 14, in update_graph
#     region_mirco_census_filtered_region_and_slct_variable = region_mirco_census.loc[(region_mirco_census['UK region'] == select_region) & (region_mirco_census[slct_xaxis2].isin(slct_v))]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py", line 4635, in isin
#     result = algorithms.isin(self._values, values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py", line 435, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
# 127.0.0.1 - - [13/Apr/2022 16:29:51] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [13/Apr/2022 16:31:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:31:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:32:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Apr/2022 16:32:02] "POST /_dash-update-component HTTP/1.1" 200 -
